# %%
import pandas as pd
low_memory=False
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
pd.options.display.max_columns = 80
pd.options.display.max_rows = 90
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
file = r'C:\Users\iasfa\Desktop\Dados_Públicos\perfil_eleitorado_ATUAL.csv'
df = pd.read_csv(file, delimiter=';',
                 error_bad_lines=False, encoding='latin1')

# %%
df.shape
# Out:
# (4306904, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4306904 entries, 0 to 4306903
# Data columns (total 21 columns):
#  #   Column                      Dtype
# ---  ------                      -----
#  0   DT_GERACAO                  object
#  1   HH_GERACAO                  object
#  2   ANO_ELEICAO                 int64
#  3   SG_UF                       object
#  4   CD_MUNICIPIO                int64
#  5   NM_MUNICIPIO                object
#  6   CD_MUN_SIT_BIOMETRIA        int64
#  7   DS_MUN_SIT_BIOMETRIA        object
#  8   NR_ZONA                     int64
#  9   CD_GENERO                   int64
#  10  DS_GENERO                   object
#  11  CD_ESTADO_CIVIL             int64
#  12  DS_ESTADO_CIVIL             object
#  13  CD_FAIXA_ETARIA             int64
#  14  DS_FAIXA_ETARIA             object
#  15  CD_GRAU_ESCOLARIDADE        int64
#  16  DS_GRAU_ESCOLARIDADE        object
#  17  QT_ELEITORES_PERFIL         int64
#  18  QT_ELEITORES_BIOMETRIA      int64
# ...

# %%
df.sample(20)
# Out:
#          DT_GERACAO HH_GERACAO  ANO_ELEICAO SG_UF  CD_MUNICIPIO  \
# 2834673  11/11/2020   21:20:42         9999    SP         70076
# 447536   11/11/2020   21:20:42         9999    PR         76791
# 3009037  11/11/2020   21:20:42         9999    PR         75353
# 4217503  11/11/2020   21:20:42         9999    SP         71455
# 3342428  11/11/2020   21:20:42         9999    RN         16187
# 1894704  11/11/2020   21:20:42         9999    MG         51870
# 1080147  11/11/2020   21:20:42         9999    MG         50350
# 2132383  11/11/2020   21:20:42         9999    RJ         60011
# 2099417  11/11/2020   21:20:42         9999    SC         81671
# 1389786  11/11/2020   21:20:42         9999    MG         42161
# 1799622  11/11/2020   21:20:42         9999    MA          9415
# 3359032  11/11/2020   21:20:42         9999    BA         39713
# 23382    11/11/2020   21:20:42         9999    MS         55000
# 1145695  11/11/2020   21:20:42         9999    PI         10049
# ...

# %%
df.groupby('QT_ELEITORES_PERFIL')['DS_ESTADO_CIVIL'].max().sort_values(ascending=False)
# Out:
# QT_ELEITORES_PERFIL
# 1        VIÚVO
# 266      VIÚVO
# 242      VIÚVO
# 241      VIÚVO
# 240      VIÚVO
#          ...
# 4288    CASADO
# 2532    CASADO
# 3140    CASADO
# 4360    CASADO
# 2476    CASADO
# Name: DS_ESTADO_CIVIL, Length: 2984, dtype: object

# %%
df['ESTADO_CIVIL_EST'] = df['SG_UF']+' '+df['DS_ESTADO_CIVIL']
df.groupby('ESTADO_CIVIL_EST').size().sort_values().tail(10).plot(kind='barh', color='GREEN',  figsize=(15, 9), title='Estado civil por estado nas eleições municipais de 2020')
# Out:
# <AxesSubplot:title={'center':'Estado civil por estado nas eleições municipais de 2020'}, ylabel='ESTADO_CIVIL_EST'>

# %%
df['ESTADO_CIVIL_FE'] = df['DS_FAIXA_ETARIA']+' '+df['DS_ESTADO_CIVIL']
jcr = df.query('NM_MUNICIPIO == "JACAREÍ"')
jcr.tail(30).plot(kind='bar', figsize=(20,13), title="Estado civil dos eleitores na cidade de Jacareí",
        x= 'ESTADO_CIVIL_FE', y='QT_ELEITORES_PERFIL', color='PINK')
# Out:
# <AxesSubplot:title={'center':'Estado civil dos eleitores na cidade de Jacareí'}, xlabel='ESTADO_CIVIL_FE'>

# %%
df['ESTADO_CIVIL_FE'] = df['DS_FAIXA_ETARIA']+' '+df['DS_ESTADO_CIVIL']
jcr = df.query('NM_MUNICIPIO == "GUARAREMA"')
jcr.tail(30).plot(kind='bar', figsize=(20,13), title="Estado civil dos eleitores na cidade de Guararema",
        x= 'ESTADO_CIVIL_FE', y='QT_ELEITORES_PERFIL', color='RED')
# Out:
# <AxesSubplot:title={'center':'Estado civil dos eleitores na cidade de Jacareí'}, xlabel='ESTADO_CIVIL_FE'>

# %%
df['ESTADO_CIVIL_FE'] = df['DS_FAIXA_ETARIA']+' '+df['DS_ESTADO_CIVIL']
jcr = df.query('NM_MUNICIPIO == "GUARULHOS"')
jcr.tail(30).plot(kind='bar', figsize=(20,13), title="Estado civil dos eleitores na cidade de Garulhos",
        x= 'ESTADO_CIVIL_FE', y='QT_ELEITORES_PERFIL', color='YELLOW')
# Out:
# <AxesSubplot:title={'center':'Estado civil dos eleitores na cidade de Jacareí'}, xlabel='ESTADO_CIVIL_FE'>

# %%
df['ESTADO_CIVIL_FE'] = df['DS_FAIXA_ETARIA']+' '+df['DS_ESTADO_CIVIL']
jcr = df.query('NM_MUNICIPIO == "CARAGUATATUBA"')
jcr.tail(30).plot(kind='bar', figsize=(20,13), title="Estado civil dos eleitores na cidade de CARAGUATATUBA",
        x= 'ESTADO_CIVIL_FE', y='QT_ELEITORES_PERFIL', color='BLUE')
# Out:
# <AxesSubplot:title={'center':'Estado civil dos eleitores na cidade de Jacareí'}, xlabel='ESTADO_CIVIL_FE'>

# %%
df['ESTADO_CIVIL_FE'] = df['DS_FAIXA_ETARIA']+' '+df['DS_ESTADO_CIVIL']
jcr = df.query('NM_MUNICIPIO == "UBATUBA"')
jcr.tail(30).plot(kind='bar', figsize=(20,13), title="Estado civil dos eleitores na cidade de Ubatuba",
        x= 'ESTADO_CIVIL_FE', y='QT_ELEITORES_PERFIL', color='BLACK')
